# %% [markdown]
# <a href="https://colab.research.google.com/github/KarimeZeraik/QSAR-and-ML/blob/main/Removing_missings_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dataset upload
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c40a8953-daf4-4085-8a96-2d1c4b1ef33e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c40a8953-daf4-4085-8a96-2d1c4b1ef33e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importing the Pandas library to help manipulate the datasets
import pandas as pd
df = pd.read_csv("dados_preprocessados_corrigidos.csv")
display (df)
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0               CHEMBL55            N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1
# 1             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 2             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 3             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 4           CHEMBL267154  C(=C1/CCCN(c2ccc(C3=NCCN3)cc2)C1)\c1ccc(C2=NCC...
# ...                  ...                                                ...
# 21605      CHEMBL2314239  O=C(Cc1ccc(O)c(O)c1)NCCCCNCCCNC(=O)Cc1ccc(O)c(...
# 21606        CHEMBL41629            C(CCCNCCCNCC1CCCCCC1)CCCNCCCNCC1CCCCCC1
# 21607      CHEMBL5274443           CN(C)CCCNc1cc(Cl)ccc1Sc1ccc(C(F)(F)F)cc1
# 21608      CHEMBL5285392  Br.C[N+](C)(CCCNc1cc(Cl)ccc1Sc1ccccc1)Cc1ccc([...
# 21609      CHEMBL2040589  Oc1cc2cc(c1O)Oc1ccc(cc1)CCc1cccc(O)c1Oc1cccc(c...
#
#       classe_bioatividade  standard_value
# ...

# %%
df_clean = df.dropna()

# %%
df_clean
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0               CHEMBL55            N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1
# 1             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 2             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 3             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 4           CHEMBL267154  C(=C1/CCCN(c2ccc(C3=NCCN3)cc2)C1)\c1ccc(C2=NCC...
# ...                  ...                                                ...
# 21605      CHEMBL2314239  O=C(Cc1ccc(O)c(O)c1)NCCCCNCCCNC(=O)Cc1ccc(O)c(...
# 21606        CHEMBL41629            C(CCCNCCCNCC1CCCCCC1)CCCNCCCNCC1CCCCCC1
# 21607      CHEMBL5274443           CN(C)CCCNc1cc(Cl)ccc1Sc1ccc(C(F)(F)F)cc1
# 21608      CHEMBL5285392  Br.C[N+](C)(CCCNc1cc(Cl)ccc1Sc1ccccc1)Cc1ccc([...
# 21609      CHEMBL2040589  Oc1cc2cc(c1O)Oc1ccc(cc1)CCc1cccc(O)c1Oc1cccc(c...
#
#       classe_bioatividade  standard_value
# ...

# %%
# Saving  dataset_final fot further analysis
df_clean.to_csv("dados_preprocessados_semmissings.csv")
