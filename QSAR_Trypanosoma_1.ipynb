# %% [markdown]
# <a href="https://colab.research.google.com/github/KarimeZeraik/QSAR-and-ML/blob/main/QSAR_Trypanosoma_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT:** Drug repurposing for trypanosomiasis.
#
# MSc. Karime Z. A. Domingues (UFPR)
#
# ***Code by Alexandre  de F. Cobre*** [Github](https://github.com/AlexandreCOBRE/code)

# %% [markdown]
# # Performing the necessary installations/uninstallations:

# %%
# !pip install fastapi kaleido python-multipart uvicorn
# !pip install chembl_webresource_client
# Out:
# Collecting fastapi
#   Downloading fastapi-0.111.1-py3-none-any.whl.metadata (26 kB)
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting python-multipart
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.30.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.2)
# Collecting fastapi-cli>=0.0.2 (from fastapi)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Collecting httpx>=0.23.0 (from fastapi)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.1.4)
# Collecting email_validator>=2.0.0 (from fastapi)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Collecting h11>=0.8 (from uvicorn)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (2024.7.4)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.23.0->fastapi) (1.2.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# Downloading fastapi-0.111.1-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 4.6 MB/s eta 0:00:00
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.0 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading uvicorn-0.30.4-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.2 MB/s eta 0:00:00
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.8 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 22.3 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 25.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 70.3 MB/s eta 0:00:00
# Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.6 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.3 MB/s eta 0:00:00
# Installing collected packages: kaleido, websockets, uvloop, python-multipart, python-dotenv, httptools, h11, dnspython, watchfiles, uvicorn, starlette, httpcore, email_validator, httpx, fastapi-cli, fastapi
# Successfully installed dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.1 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 kaleido-0.2.1 python-dotenv-1.0.1 python-multipart-0.0.9 starlette-0.37.2 uvicorn-0.30.4 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.7.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.2)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.0 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.0 MB/s eta 0:00:00
# Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.8 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-23.2.3 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# # Importing necessary libraries:

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# #**DATASET SELECTION:**
#
# ChEMBL database (https://www.ebi.ac.uk/chembl/).

# %% [markdown]
# ### Searching for target datasets: "*Trypanosoma*"

# %%
alvo = new_client.target
pesquisa_alvo = alvo.search('Trypanosoma')
ds = pd.DataFrame.from_dict(pesquisa_alvo)
ds
# Out:
#    cross_references                              organism  \
# 0                []                           Trypanosoma
# 1                []                    Trypanosoma brucei
# 2                []                     Trypanosoma cruzi
# 3                []                    Trypanosoma evansi
# 4                []                    Trypanosoma lewisi
# ..              ...                                   ...
# 72               []  Trypanosoma cruzi (strain CL Brener)
# 73               []                     Trypanosoma cruzi
# 74               []         Trypanosoma brucei equiperdum
# 75               []                Trypanosoma congolense
# 76               []               Trypanosoma cruzi Dm28c
#
#                                             pref_name  score  \
# 0                                         Trypanosoma   16.0
# 1                                  Trypanosoma brucei   14.0
# 2                                   Trypanosoma cruzi   14.0
# 3                                  Trypanosoma evansi   14.0
# 4                                  Trypanosoma lewisi   14.0
# ..                                                ...    ...
# 72                  Tyrosyl-tRNA synthetase, putative    7.0
# 73                            Proteasome subunit beta    7.0
# 74  Cleavage and polyadenylation specificity facto...    7.0
# 75                            Trypanothione reductase    7.0
# 76                                     Aminopeptidase    7.0
#
#     species_group_flag target_chembl_id  \
# 0                 True     CHEMBL612883
# 1                False     CHEMBL612849
# 2                False        CHEMBL368
# 3                False    CHEMBL1075362
# 4                False    CHEMBL2366781
# ..                 ...              ...
# 72               False    CHEMBL4662926
# 73               False    CHEMBL4662930
# 74               False    CHEMBL4665581
# 75               False    CHEMBL5291562
# 76               False    CHEMBL5305023
#
#                                     target_components     target_type   tax_id
# 0                                                  []        ORGANISM     5690
# 1                                                  []        ORGANISM     5691
# 2                                                  []        ORGANISM     5693
# 3                                                  []        ORGANISM     5697
# 4                                                  []        ORGANISM     5695
# ..                                                ...             ...      ...
# 72  [{'accession': 'Q4DSP6', 'component_descriptio...  SINGLE PROTEIN   353153
# 73  [{'accession': 'O96673', 'component_descriptio...  SINGLE PROTEIN     5693
# 74  [{'accession': 'A0A3L6L9G6', 'component_descri...  SINGLE PROTEIN   630700
# 75  [{'accession': 'P13110', 'component_descriptio...  SINGLE PROTEIN     5692
# 76  [{'accession': 'V5BWE3', 'component_descriptio...  SINGLE PROTEIN  1416333
#
# [77 rows x 9 columns]

# %% [markdown]
# ### Searching the dataset for a specific target:

# %%
# Listing all possible targets ("alvos") for visualization
lista_alvos = ds['pref_name'].tolist()
print(lista_alvos)
# Out:
# ['Trypanosoma', 'Trypanosoma brucei', 'Trypanosoma cruzi', 'Trypanosoma evansi', 'Trypanosoma lewisi', 'Trypanosoma congolense', 'Trypanosoma vivax', 'Cell membrane', 'Trypanosoma brucei brucei', 'Trypanosoma brucei gambiense', 'Trypanosoma brucei rhodesiense', 'Trypanothione reductase', 'Trypanothione reductase', 'Cruzipain', 'Adenosine transporter 1', 'Hypoxanthine-guanine phosphoribosyltransferase', 'Rhodesain', 'Nucleoside transporter 2', 'Vacuolar-type proton translocating pyrophosphatase 1', 'Hexokinase', 'Farnesyl diphosphate synthase', 'Fructose-bisphosphate aldoloase, glycosomal', 'Deoxyuridine triphosphatase', 'Trans-sialidase', 'Trypanothione reductase', 'Farnesyltransferase, putative', 'Pteridine reductase, putative', 'Dihydrofolate reductase-thymidylate synthase', '6-phospho-1-fructokinase', 'Glyceraldehyde-3-phosphate dehydrogenase, glycosomal', 'IAG-nucleoside hydrolase', 'Glucose-6-phosphate 1-dehydrogenase', 'Cathepsin B-like cysteine protease', 'Farnesyl synthetase, putative', 'Triosephosphate isomerase, glycosomal', 'Sterol 14-alpha demethylase', 'Metacaspase', 'Metacaspase', 'Bifunctional dihydrofolate reductase-thymidylate synthase', 'UDP-galactose 4-epimerase', 'S-adenosylmethionine decarboxylase proenzyme', 'Cyclic nucleotide specific phosphodiesterase', 'Phosphoglycerate kinase, glycosomal', 'Hexokinase', '6-phosphogluconate dehydrogenase, decarboxylating, putative', 'Class 1 phosphodiesterase PDEB1', 'Methionyl-tRNA synthetase, putative', 'Putative uncharacterized protein', 'Dolichol-phosphate-mannose synthase', 'Phosphoglycerate kinase', 'Kinetoplast DNA', '6-phospho-1-fructokinase, putative', 'Trypanothione synthetase', '6-phosphogluconolactonase', 'Tryparedoxin peroxidase', 'Inosine-adenosine-guanosine-nucleoside hydrolase', 'Spermidine synthase', 'Tubulin alpha chain', 'Glycylpeptide N-tetradecanoyltransferase', 'Trans-sialidase', 'RNA-editing ligase 1, mitochondrial', 'S-adenosylmethionine decarboxylase proenzyme', 'Putative amino acid permease/transporter', 'Alternative oxidase, mitochondrial', 'Lanosterol 14-alpha-demethylase', 'Leucyl-tRNA synthetase, putative', 'Carbonic anhydrase-like protein, putative', 'Superoxide dismutase', 'Putative amino acid transporter PAT12', 'DNA', 'Phosphodiesterase', 'Histidine--tRNA ligase', 'Tyrosyl-tRNA synthetase, putative', 'Proteasome subunit beta', 'Cleavage and polyadenylation specificity factor subunit', 'Trypanothione reductase', 'Aminopeptidase']

# %%
# Defining the target to be searched
alvo = "Trypanosoma"

# Checking if any element in pref_name contains this target:
contains_alvo = ds['pref_name'].str.contains(alvo)

# Getting the indices of the rows with the defined target:
indices_com_alvo = ds[contains_alvo].index.tolist()

if contains_alvo.any():
    print(f"At least one element contains the term: {alvo}")
    print(f"Indices of the rows with the term'{alvo}': {indices_com_alvo}")
else:
    print(f"No element contains the term: {alvo}")
# Out:
# At least one element contains the term: Trypanosoma
# Indices of the rows with the term'Trypanosoma': [0, 1, 2, 3, 4, 5, 6, 8, 9, 10]

# %% [markdown]
# ### Converting IC50 values to a standard concentration unit (molar - M) and generating a single dataframe:

# %%
# prompt: select rows from df['target_chembl_id']

ensaios = ds[ds['target_chembl_id'].isin(['CHEMBL368', 'CHEMBL612849', 'CHEMBL612851', 'CHEMBL612348', 'CHEMBL613768'])]

# %%
indices_com_ensaio = ensaios.index
indices_com_ensaio
# Out:
# Index([1, 2, 8, 9, 10], dtype='int64')

# %%
# Creating a list to store individual DataFrames

dfs = []




# Iterating over the different indices:

for i in indices_com_ensaio :

    df_nM_i = []

    df_uM_i = []

    df_mM_i = []

    df_M_i = []

    ds_selecionado_i = ds.target_chembl_id[i]




    # Filtering bioactive compounds with IC50 data, in nM units, for each index:

    atividade = new_client.activity

    resultado_nM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="nM")




    # Filtering bioactive compounds with IC50 data, in µM units, for each index:

    resultado_uM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="uM")




    # Filtering bioactive compounds with IC50 data, in mM units, for each index:

    resultado_mM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="mM")




    # Filtering bioactive compounds with IC50 data, in M units, for each index:

    resultado_M = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="M")




    # Creating a DataFrame for each unit:

    df_nM_i = pd.DataFrame.from_dict(resultado_nM)

    df_uM_i = pd.DataFrame.from_dict(resultado_uM)

    df_mM_i = pd.DataFrame.from_dict(resultado_mM)

    df_M_i = pd.DataFrame.from_dict(resultado_M)




    # Converting each DataFrame to a standard unit (M):

    if not df_nM_i.empty and 'value' in df_nM_i:

        df_nM_i['value'] = df_nM_i['value'].astype(float)

        df_nM_i['value'] *= 1e-9

    else:

        pass




    if not df_uM_i.empty and 'value' in df_uM_i:

        df_uM_i['value'] = df_uM_i['value'].astype(float)

        df_uM_i['value'] *= 1e-6

    else:

        pass




    if not df_mM_i.empty and 'value' in df_mM_i:

        df_mM_i['value'] = df_mM_i['value'].astype(float)

        df_mM_i['value'] *= 1e-3

    else:

        pass




    if not df_M_i.empty and 'value' in df_M_i:

        df_M_i['value'] = df_M_i['value'].astype(float)

    else:

        pass




    # Adding the DataFrames to the list:

    dfs.append(df_nM_i)

    dfs.append(df_uM_i)

    dfs.append(df_mM_i)

    dfs.append(df_M_i)




# Concatenating the individual DataFrames into a single DataFrame:

df_assays = pd.concat(dfs, ignore_index=True)

df_assays['units'] = 'M'




# Displaying the final DataFrame:

display(df_assays)
# Out:
#       action_type activity_comment  activity_id activity_properties  \
# 0            None             None       773784                  []
# 1            None             None      1185841                  []
# 2            None             None      1185842                  []
# 3            None             None      1185844                  []
# 4            None             None      1185893                  []
# ...           ...              ...          ...                 ...
# 21639        None             None     25105234                  []
# 21640        None             None     25105235                  []
# 21641        None             None     25105309                  []
# 21642        None             None     25105346                  []
# 21643        None             None     25106394                  []
#
#       assay_chembl_id                                  assay_description  \
# 0        CHEMBL814775  Compound was evaluated for anti-parasitic acti...
# 1        CHEMBL719973  In vitro inhibitory concentration against mice...
# 2        CHEMBL719974  In vitro inhibitory concentration against mice...
# 3        CHEMBL719976  In vitro inhibitory concentration against mous...
# 4        CHEMBL719973  In vitro inhibitory concentration against mice...
# ...               ...                                                ...
# 21639   CHEMBL5263053  Antiprotozoal activity against Trypanosoma bru...
# 21640   CHEMBL5263053  Antiprotozoal activity against Trypanosoma bru...
# 21641   CHEMBL5263092  Antiprotozoal activity against Trypanosoma bru...
# 21642   CHEMBL5263119  Antiprotozoal activity against Trypanosoma bru...
# 21643   CHEMBL5263422  Antimalarial activity against drug sensitive T...
#
#       assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0              F                    None                   None  BAO_0000190
# 1              F                    None                   None  BAO_0000190
# 2              F                    None                   None  BAO_0000190
# 3              F                    None                   None  BAO_0000190
# 4              F                    None                   None  BAO_0000190
# ...          ...                     ...                    ...          ...
# 21639          F                    None                   None  BAO_0000190
# 21640          F                    None                   None  BAO_0000190
# 21641          F                    None                   None  BAO_0000190
# 21642          F                    None                   None  BAO_0000190
# 21643          F                    None                   None  BAO_0000190
#
#        ...                 target_organism                target_pref_name  \
# 0      ...              Trypanosoma brucei              Trypanosoma brucei
# 1      ...              Trypanosoma brucei              Trypanosoma brucei
# 2      ...              Trypanosoma brucei              Trypanosoma brucei
# 3      ...              Trypanosoma brucei              Trypanosoma brucei
# 4      ...              Trypanosoma brucei              Trypanosoma brucei
# ...    ...                             ...                             ...
# 21639  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21640  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21641  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21642  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21643  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
#
#       target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0              5691       None  None  IC50     M  UO_0000065        None
# 1              5691       None  None  IC50     M  UO_0000065        None
# 2              5691       None  None  IC50     M  UO_0000065        None
# 3              5691       None  None  IC50     M  UO_0000065        None
# 4              5691       None  None  IC50     M  UO_0000065        None
# ...             ...        ...   ...   ...   ...         ...         ...
# 21639         31286       None  None  IC50     M  UO_0000065        None
# 21640         31286       None  None  IC50     M  UO_0000065        None
# 21641         31286       None  None  IC50     M  UO_0000065        None
# 21642         31286       None  None  IC50     M  UO_0000065        None
# 21643         31286       None  None  IC50     M  UO_0000065        None
#
#               value
# 0      3.500000e-08
# 1      5.800000e-08
# 2      1.600000e-08
# 3      1.650000e-08
# 4      7.100000e-08
# ...             ...
# 21639  5.900000e-06
# 21640  1.600000e-07
# 21641  1.200000e-06
# 21642  6.000000e-07
# 21643  2.090000e-06
#
# [21644 rows x 46 columns]

# %%
df_assays["value"].isnull().sum()
# Out:
# 34

# %%
# Assuming your DataFrame is df_assays
df_assays.dropna(subset=['value'], inplace=True)

# %%
df_assays
# Out:
#       action_type activity_comment  activity_id activity_properties  \
# 0            None             None       773784                  []
# 1            None             None      1185841                  []
# 2            None             None      1185842                  []
# 3            None             None      1185844                  []
# 4            None             None      1185893                  []
# ...           ...              ...          ...                 ...
# 21639        None             None     25105234                  []
# 21640        None             None     25105235                  []
# 21641        None             None     25105309                  []
# 21642        None             None     25105346                  []
# 21643        None             None     25106394                  []
#
#       assay_chembl_id                                  assay_description  \
# 0        CHEMBL814775  Compound was evaluated for anti-parasitic acti...
# 1        CHEMBL719973  In vitro inhibitory concentration against mice...
# 2        CHEMBL719974  In vitro inhibitory concentration against mice...
# 3        CHEMBL719976  In vitro inhibitory concentration against mous...
# 4        CHEMBL719973  In vitro inhibitory concentration against mice...
# ...               ...                                                ...
# 21639   CHEMBL5263053  Antiprotozoal activity against Trypanosoma bru...
# 21640   CHEMBL5263053  Antiprotozoal activity against Trypanosoma bru...
# 21641   CHEMBL5263092  Antiprotozoal activity against Trypanosoma bru...
# 21642   CHEMBL5263119  Antiprotozoal activity against Trypanosoma bru...
# 21643   CHEMBL5263422  Antimalarial activity against drug sensitive T...
#
#       assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0              F                    None                   None  BAO_0000190
# 1              F                    None                   None  BAO_0000190
# 2              F                    None                   None  BAO_0000190
# 3              F                    None                   None  BAO_0000190
# 4              F                    None                   None  BAO_0000190
# ...          ...                     ...                    ...          ...
# 21639          F                    None                   None  BAO_0000190
# 21640          F                    None                   None  BAO_0000190
# 21641          F                    None                   None  BAO_0000190
# 21642          F                    None                   None  BAO_0000190
# 21643          F                    None                   None  BAO_0000190
#
#        ...                 target_organism                target_pref_name  \
# 0      ...              Trypanosoma brucei              Trypanosoma brucei
# 1      ...              Trypanosoma brucei              Trypanosoma brucei
# 2      ...              Trypanosoma brucei              Trypanosoma brucei
# 3      ...              Trypanosoma brucei              Trypanosoma brucei
# 4      ...              Trypanosoma brucei              Trypanosoma brucei
# ...    ...                             ...                             ...
# 21639  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21640  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21641  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21642  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
# 21643  ...  Trypanosoma brucei rhodesiense  Trypanosoma brucei rhodesiense
#
#       target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0              5691       None  None  IC50     M  UO_0000065        None
# 1              5691       None  None  IC50     M  UO_0000065        None
# 2              5691       None  None  IC50     M  UO_0000065        None
# 3              5691       None  None  IC50     M  UO_0000065        None
# 4              5691       None  None  IC50     M  UO_0000065        None
# ...             ...        ...   ...   ...   ...         ...         ...
# 21639         31286       None  None  IC50     M  UO_0000065        None
# 21640         31286       None  None  IC50     M  UO_0000065        None
# 21641         31286       None  None  IC50     M  UO_0000065        None
# 21642         31286       None  None  IC50     M  UO_0000065        None
# 21643         31286       None  None  IC50     M  UO_0000065        None
#
#               value
# 0      3.500000e-08
# 1      5.800000e-08
# 2      1.600000e-08
# 3      1.650000e-08
# 4      7.100000e-08
# ...             ...
# 21639  5.900000e-06
# 21640  1.600000e-07
# 21641  1.200000e-06
# 21642  6.000000e-07
# 21643  2.090000e-06
#
# [21610 rows x 46 columns]

# %%
# Assigning the class of the compounds

classe_bioatividade = []
for i in df_assays.standard_value:
    if float(i) > 0.0001:
        classe_bioatividade.append("Inactive")
    elif float(i) <= 0.00001:
        classe_bioatividade.append("Active")
    else:
        classe_bioatividade.append("Intermediate")

# %%
# Visualizing bioactive compounds
df_assays.molecule_chembl_id
# Out:
# 0             CHEMBL55
# 1           CHEMBL9126
# 2           CHEMBL9126
# 3           CHEMBL9126
# 4         CHEMBL267154
#              ...
# 21639    CHEMBL2314239
# 21640      CHEMBL41629
# 21641    CHEMBL5274443
# 21642    CHEMBL5285392
# 21643    CHEMBL2040589
# Name: molecule_chembl_id, Length: 21610, dtype: object

# %%
# Iterating over bioactive compounds
mol_cid = []
for i in df_assays.molecule_chembl_id:
    mol_cid.append(i)

# %%
# Printing the variable mol_cid
mol_cid
# Out:
# ['CHEMBL55',
#  'CHEMBL9126',
#  'CHEMBL9126',
#  'CHEMBL9126',
#  'CHEMBL267154',
#  'CHEMBL267154',
#  'CHEMBL267154',
#  'CHEMBL55',
#  'CHEMBL55',
#  'CHEMBL55',
#  'CHEMBL9341',
#  'CHEMBL9341',
#  'CHEMBL9341',
#  'CHEMBL9025',
#  'CHEMBL9025',
#  'CHEMBL9025',
#  'CHEMBL276449',
#  'CHEMBL276449',
#  'CHEMBL276449',
#  'CHEMBL9531',
#  'CHEMBL9531',
#  'CHEMBL9531',
#  'CHEMBL9516',
#  'CHEMBL9516',
#  'CHEMBL9516',
#  'CHEMBL2311124',
#  'CHEMBL2311124',
#  'CHEMBL2311124',
#  'CHEMBL9479',
#  'CHEMBL9479',
#  'CHEMBL9479',
#  'CHEMBL166',
#  'CHEMBL9053',
#  'CHEMBL9053',
#  'CHEMBL9053',
#  'CHEMBL25526',
#  'CHEMBL25526',
#  'CHEMBL25526',
#  'CHEMBL9121',
#  'CHEMBL9121',
#  'CHEMBL9121',
#  'CHEMBL269032',
#  'CHEMBL269032',
#  'CHEMBL269032',
#  'CHEMBL9185',
#  'CHEMBL9185',
#  'CHEMBL9185',
#  'CHEMBL266808',
#  'CHEMBL266808',
#  'CHEMBL266808',
#  'CHEMBL9490',
#  'CHEMBL9490',
#  'CHEMBL9490',
#  'CHEMBL9391',
#  'CHEMBL9391',
#  'CHEMBL9391',
#  'CHEMBL8892',
#  'CHEMBL8892',
#  'CHEMBL8892',
#  'CHEMBL55',
#  'CHEMBL35241',
#  'CHEMBL265502',
#  'CHEMBL192069',
#  'CHEMBL1254447',
#  'CHEMBL536047',
#  'CHEMBL1684448',
#  'CHEMBL1684447',
#  'CHEMBL1684446',
#  'CHEMBL1802090',
#  'CHEMBL1801715',
#  'CHEMBL1801716',
#  'CHEMBL1801717',
#  'CHEMBL1801718',
#  'CHEMBL1801719',
#  'CHEMBL1801720',
#  'CHEMBL1801721',
#  'CHEMBL1801722',
#  'CHEMBL1800092',
#  'CHEMBL1801723',
#  'CHEMBL1801724',
#  'CHEMBL1801725',
#  'CHEMBL1801726',
#  'CHEMBL1801727',
#  'CHEMBL1801728',
#  'CHEMBL1801729',
#  'CHEMBL1801730',
#  'CHEMBL1801731',
#  'CHEMBL1801732',
#  'CHEMBL1801733',
#  'CHEMBL1802137',
#  'CHEMBL1802138',
#  'CHEMBL1802139',
#  'CHEMBL1801717',
#  'CHEMBL1801718',
#  'CHEMBL1801719',
#  'CHEMBL1831290',
#  'CHEMBL3110070',
#  'CHEMBL3110070',
#  'CHEMBL305686',
#  'CHEMBL305686',
#  'CHEMBL305686',
#  'CHEMBL3818219',
#  'CHEMBL3197634',
#  'CHEMBL3819167',
#  'CHEMBL3817917',
#  'CHEMBL3819053',
#  'CHEMBL3818569',
#  'CHEMBL3818375',
#  'CHEMBL3818769',
#  'CHEMBL3818147',
#  'CHEMBL3819335',
#  'CHEMBL3819334',
#  'CHEMBL3818078',
#  'CHEMBL3819375',
#  'CHEMBL3818897',
#  'CHEMBL3212967',
#  'CHEMBL3818096',
#  'CHEMBL3818188',
#  'CHEMBL296468',
#  'CHEMBL7064',
#  'CHEMBL488436',
#  'CHEMBL4475773',
#  'CHEMBL3218578',
#  'CHEMBL564829',
#  'CHEMBL1236962',
#  'CHEMBL1774055',
#  'CHEMBL2103840',
#  'CHEMBL1765602',
#  'CHEMBL55',
#  'CHEMBL2111280',
#  'CHEMBL2111280',
#  'CHEMBL2111280',
#  'CHEMBL2111280',
#  'CHEMBL2111248',
#  'CHEMBL2111248',
#  'CHEMBL2111248',
#  'CHEMBL2111283',
#  'CHEMBL2111283',
#  'CHEMBL2111283',
#  'CHEMBL2111283',
#  'CHEMBL346319',
#  'CHEMBL346319',
#  'CHEMBL2111249',
#  'CHEMBL2111249',
#  'CHEMBL2051757',
#  'CHEMBL2051757',
#  'CHEMBL2051757',
#  'CHEMBL2051757',
#  'CHEMBL347186',
#  'CHEMBL347186',
#  'CHEMBL347186',
#  'CHEMBL347186',
#  'CHEMBL2111282',
#  'CHEMBL2111282',
#  'CHEMBL2111282',
#  'CHEMBL2111282',
#  'CHEMBL2111246',
#  'CHEMBL2111246',
#  'CHEMBL2111247',
#  'CHEMBL2111247',
#  'CHEMBL2111247',
#  'CHEMBL2111247',
#  'CHEMBL44025',
#  'CHEMBL44025',
#  'CHEMBL44025',
#  'CHEMBL43390',
#  'CHEMBL43390',
#  'CHEMBL43390',
#  'CHEMBL43390',
#  'CHEMBL43494',
#  'CHEMBL43494',
#  'CHEMBL44040',
#  'CHEMBL44040',
#  'CHEMBL43495',
#  'CHEMBL43495',
#  'CHEMBL43495',
#  'CHEMBL44083',
#  'CHEMBL44083',
#  'CHEMBL44083',
#  'CHEMBL44083',
#  'CHEMBL44083',
#  'CHEMBL44083',
#  'CHEMBL44083',
#  'CHEMBL44083',
#  'CHEMBL416078',
#  'CHEMBL416078',
#  'CHEMBL416078',
#  'CHEMBL416078',
#  'CHEMBL40258',
#  'CHEMBL40258',
#  'CHEMBL40258',
#  'CHEMBL40258',
#  'CHEMBL296119',
#  'CHEMBL296119',
#  'CHEMBL296119',
#  'CHEMBL296119',
#  'CHEMBL40414',
#  'CHEMBL40414',
#  'CHEMBL44039',
#  'CHEMBL44039',
#  'CHEMBL44039',
#  'CHEMBL44039',
#  'CHEMBL289450',
#  'CHEMBL289450',
#  'CHEMBL289450',
#  'CHEMBL289450',
#  'CHEMBL296777',
#  'CHEMBL296777',
#  'CHEMBL296777',
#  'CHEMBL296777',
#  'CHEMBL41629',
#  'CHEMBL41629',
#  'CHEMBL41629',
#  'CHEMBL41629',
#  'CHEMBL36',
#  'CHEMBL334695',
#  'CHEMBL274031',
#  'CHEMBL343127',
#  'CHEMBL31547',
#  'CHEMBL334919',
#  'CHEMBL22',
#  'CHEMBL31235',
#  'CHEMBL343271',
#  'CHEMBL31946',
#  'CHEMBL137448',
#  'CHEMBL30734',
#  'CHEMBL326989',
#  'CHEMBL138230',
#  'CHEMBL18967',
#  'CHEMBL137305',
#  'CHEMBL285209',
#  'CHEMBL137641',
#  'CHEMBL296119',
#  'CHEMBL296119',
#  'CHEMBL296119',
#  'CHEMBL296119',
#  'CHEMBL3392183',
#  'CHEMBL86940',
#  'CHEMBL86940',
#  'CHEMBL86940',
#  'CHEMBL86940',
#  'CHEMBL447829',
#  'CHEMBL447829',
#  'CHEMBL447829',
#  'CHEMBL447829',
#  'CHEMBL3392184',
#  'CHEMBL86523',
#  'CHEMBL86523',
#  'CHEMBL40258',
#  'CHEMBL40258',
#  'CHEMBL40258',
#  'CHEMBL40258',
#  'CHEMBL416078',
#  'CHEMBL416078',
#  'CHEMBL416078',
#  'CHEMBL416078',
#  'CHEMBL44039',
#  'CHEMBL44039',
#  'CHEMBL44039',
#  'CHEMBL44039',
#  'CHEMBL41629',
#  'CHEMBL41629',
#  'CHEMBL41629',
#  'CHEMBL41629',
#  'CHEMBL86587',
#  'CHEMBL86587',
#  'CHEMBL86435',
#  'CHEMBL86435',
#  'CHEMBL86435',
#  'CHEMBL86435',
#  'CHEMBL313792',
#  'CHEMBL313792',
#  'CHEMBL313792',
#  'CHEMBL87326',
#  'CHEMBL87326',
#  'CHEMBL33387',
#  'CHEMBL33387',
#  'CHEMBL33387',
#  'CHEMBL33387',
#  'CHEMBL43390',
#  'CHEMBL43390',
#  'CHEMBL43390',
#  'CHEMBL43390',
#  'CHEMBL289450',
#  'CHEMBL289450',
#  'CHEMBL289450',
#  'CHEMBL289450',
#  'CHEMBL298362',
#  'CHEMBL298794',
#  'CHEMBL298774',
#  'CHEMBL55',
#  'CHEMBL52182',
#  'CHEMBL51330',
#  'CHEMBL53263',
#  'CHEMBL296401',
#  'CHEMBL53423',
#  'CHEMBL54078',
#  'CHEMBL52905',
#  'CHEMBL52127',
#  'CHEMBL53698',
#  'CHEMBL52478',
#  'CHEMBL51916',
#  'CHEMBL54551',
#  'CHEMBL431345',
#  'CHEMBL52017',
#  'CHEMBL55225',
#  'CHEMBL53153',
#  'CHEMBL54094',
#  'CHEMBL265502',
#  'CHEMBL52597',
#  'CHEMBL298397',
#  'CHEMBL295960',
#  'CHEMBL51746',
#  'CHEMBL53033',
#  'CHEMBL54012',
#  'CHEMBL298557',
#  'CHEMBL299079',
#  'CHEMBL299414',
#  'CHEMBL53586',
#  'CHEMBL298564',
#  'CHEMBL54952',
#  'CHEMBL116390',
#  'CHEMBL114894',
#  'CHEMBL113666',
#  'CHEMBL324609',
#  'CHEMBL114160',
#  'CHEMBL113708',
#  'CHEMBL114616',
#  'CHEMBL117133',
#  'CHEMBL117876',
#  'CHEMBL114269',
#  'CHEMBL116018',
#  'CHEMBL114416',
#  'CHEMBL325268',
#  'CHEMBL116897',
#  'CHEMBL334040',
#  'CHEMBL117442',
#  'CHEMBL117535',
#  'CHEMBL117534',
#  'CHEMBL323922',
#  'CHEMBL113843',
#  'CHEMBL420687',
#  'CHEMBL325269',
#  'CHEMBL116916',
#  'CHEMBL117064',
#  'CHEMBL118340',
#  'CHEMBL118066',
#  'CHEMBL115592',
#  'CHEMBL118855',
#  'CHEMBL119649',
#  'CHEMBL118165',
#  'CHEMBL333481',
#  'CHEMBL432423',
#  'CHEMBL323909',
#  'CHEMBL115585',
#  'CHEMBL117831',
#  'CHEMBL119096',
#  'CHEMBL119475',
#  'CHEMBL118916',
#  'CHEMBL2051757',
#  'CHEMBL2051757',
#  'CHEMBL2051757',
#  'CHEMBL2051757',
#  'CHEMBL443023',
#  'CHEMBL115433',
#  'CHEMBL119834',
#  'CHEMBL332478',
#  'CHEMBL331251',
#  'CHEMBL117926',
#  'CHEMBL119102',
#  'CHEMBL118343',
#  'CHEMBL440898',
#  'CHEMBL118915',
#  'CHEMBL118838',
#  'CHEMBL332113',
#  'CHEMBL55359',
#  'CHEMBL55358',
#  'CHEMBL55140',
#  'CHEMBL417932',
#  'CHEMBL55214',
#  'CHEMBL434024',
#  'CHEMBL52761',
#  'CHEMBL56556',
#  'CHEMBL301471',
#  'CHEMBL923',
#  'CHEMBL55886',
#  'CHEMBL55812',
#  'CHEMBL293522',
#  'CHEMBL299491',
#  'CHEMBL299988',
#  'CHEMBL301247',
#  'CHEMBL834',
#  'CHEMBL298771',
#  'CHEMBL870',
#  'CHEMBL82641',
#  'CHEMBL82641',
#  'CHEMBL82641',
#  'CHEMBL82641',
#  'CHEMBL85189',
#  'CHEMBL85189',
#  'CHEMBL85189',
#  'CHEMBL85189',
#  'CHEMBL86096',
#  'CHEMBL86096',
#  'CHEMBL86096',
#  'CHEMBL86096',
#  'CHEMBL86281',
#  'CHEMBL86281',
#  'CHEMBL86281',
#  'CHEMBL86281',
#  'CHEMBL84221',
#  'CHEMBL84221',
#  'CHEMBL84221',
#  'CHEMBL84221',
#  'CHEMBL85161',
#  'CHEMBL85161',
#  'CHEMBL85161',
#  'CHEMBL85161',
#  'CHEMBL85198',
#  'CHEMBL85198',
#  'CHEMBL85198',
#  'CHEMBL85198',
#  'CHEMBL62048',
#  'CHEMBL62048',
#  'CHEMBL62048',
#  'CHEMBL62048',
#  'CHEMBL310207',
#  'CHEMBL310207',
#  'CHEMBL310207',
#  'CHEMBL310207',
#  'CHEMBL121434',
#  'CHEMBL265502',
#  'CHEMBL334308',
#  'CHEMBL121345',
#  'CHEMBL121001',
#  'CHEMBL121177',
#  'CHEMBL119769',
#  'CHEMBL120734',
#  'CHEMBL124355',
#  'CHEMBL538157',
#  'CHEMBL122675',
#  'CHEMBL432231',
#  'CHEMBL338511',
#  'CHEMBL121537',
#  'CHEMBL121573',
#  'CHEMBL120925',
#  'CHEMBL121196',
#  'CHEMBL120356',
#  'CHEMBL121071',
#  'CHEMBL177872',
#  'CHEMBL3143659',
#  'CHEMBL172782',
#  'CHEMBL353318',
#  'CHEMBL175127',
#  'CHEMBL62192',
#  'CHEMBL301405',
#  'CHEMBL61970',
#  'CHEMBL418503',
#  'CHEMBL58857',
#  'CHEMBL293899',
#  'CHEMBL96761',
#  'CHEMBL96761',
#  'CHEMBL96761',
#  'CHEMBL96761',
#  'CHEMBL93014',
#  'CHEMBL93014',
#  'CHEMBL93014',
#  'CHEMBL93014',
#  'CHEMBL92122',
#  'CHEMBL92122',
#  'CHEMBL92122',
#  'CHEMBL92122',
#  'CHEMBL93088',
#  'CHEMBL93088',
#  'CHEMBL93088',
#  'CHEMBL93088',
#  'CHEMBL92123',
#  'CHEMBL92123',
#  'CHEMBL92123',
#  'CHEMBL92123',
#  'CHEMBL93314',
#  'CHEMBL93314',
#  'CHEMBL93314',
#  'CHEMBL93314',
#  'CHEMBL59755',
#  'CHEMBL60505',
#  'CHEMBL413376',
#  'CHEMBL61588',
#  'CHEMBL60144',
#  'CHEMBL60093',
#  'CHEMBL60487',
#  'CHEMBL60085',
#  'CHEMBL290960',
#  'CHEMBL290960',
#  'CHEMBL290960',
#  'CHEMBL110',
#  'CHEMBL110',
#  'CHEMBL110',
#  'CHEMBL423172',
#  'CHEMBL423172',
#  'CHEMBL423172',
#  'CHEMBL193320',
#  'CHEMBL193320',
#  'CHEMBL193320',
#  'CHEMBL362928',
#  'CHEMBL362928',
#  'CHEMBL362928',
#  'CHEMBL208745',
#  'CHEMBL208713',
#  'CHEMBL210961',
#  'CHEMBL209085',
#  'CHEMBL379972',
#  'CHEMBL245898',
#  'CHEMBL959',
#  'CHEMBL660',
#  'CHEMBL392595',
#  'CHEMBL438333',
#  'CHEMBL247304',
#  'CHEMBL396099',
#  'CHEMBL254227',
#  'CHEMBL254618',
#  'CHEMBL400542',
#  'CHEMBL254617',
#  'CHEMBL254412',
#  'CHEMBL255038',
#  'CHEMBL400663',
#  'CHEMBL254828',
#  'CHEMBL436637',
#  'CHEMBL254827',
#  'CHEMBL400522',
#  'CHEMBL252121',
#  'CHEMBL398504',
#  'CHEMBL251923',
#  'CHEMBL399027',
#  'CHEMBL252729',
#  'CHEMBL252933',
#  'CHEMBL253831',
#  'CHEMBL398708',
#  'CHEMBL253830',
#  'CHEMBL253829',
#  'CHEMBL398507',
#  'CHEMBL253611',
#  'CHEMBL255080',
#  'CHEMBL400454',
#  'CHEMBL400453',
#  'CHEMBL255079',
#  'CHEMBL400248',
#  'CHEMBL252558',
#  'CHEMBL398311',
#  'CHEMBL252363',
#  'CHEMBL252362',
#  'CHEMBL399513',
#  'CHEMBL252361',
#  'CHEMBL252158',
#  'CHEMBL252157',
#  'CHEMBL399095',
#  'CHEMBL252156',
#  'CHEMBL251959',
#  'CHEMBL399094',
#  'CHEMBL252360',
#  'CHEMBL402052',
#  'CHEMBL252359',
#  'CHEMBL252934',
#  'CHEMBL398505',
#  'CHEMBL400543',
#  'CHEMBL254619',
#  'CHEMBL1569',
#  'CHEMBL535396',
#  'CHEMBL270260',
#  'CHEMBL269893',
#  'CHEMBL270339',
#  'CHEMBL409316',
#  'CHEMBL273129',
#  'CHEMBL429426',
#  'CHEMBL404602',
#  'CHEMBL537456',
#  'CHEMBL405896',
#  'CHEMBL537471',
#  'CHEMBL270540',
#  'CHEMBL270541',
#  'CHEMBL273132',
#  'CHEMBL539354',
#  'CHEMBL406103',
#  'CHEMBL273131',
#  'CHEMBL271608',
#  'CHEMBL261602',
#  'CHEMBL261601',
#  'CHEMBL270471',
#  'CHEMBL411451',
#  'CHEMBL507331',
#  'CHEMBL522043',
#  'CHEMBL495450',
#  'CHEMBL495449',
#  'CHEMBL510953',
#  'CHEMBL494204',
#  'CHEMBL523186',
#  'CHEMBL505434',
#  'CHEMBL660',
#  'CHEMBL472483',
#  'CHEMBL959',
#  'CHEMBL169',
#  'CHEMBL410525',
#  'CHEMBL505029',
#  'CHEMBL502715',
#  'CHEMBL507467',
#  'CHEMBL450120',
#  'CHEMBL448388',
#  'CHEMBL503930',
#  'CHEMBL506853',
#  'CHEMBL449323',
#  'CHEMBL500001',
#  'CHEMBL449257',
#  'CHEMBL508539',
#  'CHEMBL399873',
#  'CHEMBL448464',
#  'CHEMBL959',
#  'CHEMBL660',
#  'CHEMBL959',
#  'CHEMBL592226',
#  'CHEMBL591993',
#  'CHEMBL591766',
#  'CHEMBL807',
#  'CHEMBL115433',
#  'CHEMBL117064',
#  'CHEMBL119834',
#  'CHEMBL440898',
#  'CHEMBL119475',
#  'CHEMBL118916',
#  'CHEMBL118066',
#  'CHEMBL118343',
#  'CHEMBL118855',
#  'CHEMBL118340',
#  'CHEMBL331251',
#  'CHEMBL119649',
#  'CHEMBL333481',
#  'CHEMBL432423',
#  'CHEMBL443023',
#  'CHEMBL1213379',
#  'CHEMBL1213380',
#  'CHEMBL1213381',
#  'CHEMBL1213382',
#  'CHEMBL1213421',
#  'CHEMBL1213422',
#  'CHEMBL1213423',
#  'CHEMBL1213424',
#  'CHEMBL1213461',
#  'CHEMBL485019',
#  'CHEMBL1213462',
#  'CHEMBL1213463',
#  'CHEMBL119102',
#  'CHEMBL117831',
#  'CHEMBL323909',
#  'CHEMBL119096',
#  'CHEMBL115585',
#  'CHEMBL144896',
#  'CHEMBL1256965',
#  'CHEMBL1256990',
#  'CHEMBL1256991',
#  'CHEMBL1257016',
#  'CHEMBL1257017',
#  'CHEMBL1257018',
#  'CHEMBL290960',
#  'CHEMBL1256799',
#  'CHEMBL1256401',
#  'CHEMBL1256989',
#  'CHEMBL1256966',
#  'CHEMBL1256964',
#  'CHEMBL1256928',
#  'CHEMBL1256927',
#  'CHEMBL1256926',
#  'CHEMBL1256888',
#  'CHEMBL1256887',
#  'CHEMBL1256855',
#  'CHEMBL1256823',
#  'CHEMBL1256822',
#  'CHEMBL1256821',
#  'CHEMBL166',
#  'CHEMBL1275718',
#  'CHEMBL1275767',
#  'CHEMBL1275769',
#  'CHEMBL1275717',
#  'CHEMBL1200010',
#  'CHEMBL959',
#  'CHEMBL1275695',
#  'CHEMBL566743',
#  'CHEMBL1644655',
#  'CHEMBL1644656',
#  'CHEMBL1644657',
#  'CHEMBL1644658',
#  'CHEMBL1644659',
#  'CHEMBL1644660',
#  'CHEMBL1644661',
#  'CHEMBL1644662',
#  'CHEMBL1644663',
#  'CHEMBL1644664',
#  'CHEMBL1644665',
#  'CHEMBL1644666',
#  'CHEMBL1644667',
#  'CHEMBL55',
#  'CHEMBL265502',
#  'CHEMBL1650840',
#  'CHEMBL1650838',
#  'CHEMBL321399',
#  'CHEMBL23330',
#  'CHEMBL290960',
#  'CHEMBL111860',
#  'CHEMBL112126',
#  'CHEMBL1650839',
#  'CHEMBL324103',
#  'CHEMBL112527',
#  'CHEMBL536047',
#  'CHEMBL1684446',
#  'CHEMBL1684447',
#  'CHEMBL1684448',
#  'CHEMBL1684449',
#  'CHEMBL1684450',
#  'CHEMBL1684451',
#  'CHEMBL1684452',
#  'CHEMBL539051',
#  'CHEMBL1684453',
#  'CHEMBL1684454',
#  'CHEMBL1684455',
#  'CHEMBL1684456',
#  'CHEMBL1684457',
#  'CHEMBL1684458',
#  'CHEMBL1684459',
#  'CHEMBL1684460',
#  'CHEMBL1684461',
#  'CHEMBL1684462',
#  'CHEMBL959',
#  'CHEMBL537471',
#  'CHEMBL1802086',
#  'CHEMBL1802087',
#  'CHEMBL247304',
#  'CHEMBL392595',
#  'CHEMBL1933084',
#  'CHEMBL1934729',
#  'CHEMBL1934730',
#  'CHEMBL1934731',
#  'CHEMBL1934732',
#  'CHEMBL1934733',
#  'CHEMBL1934734',
#  'CHEMBL959',
#  'CHEMBL807',
#  'CHEMBL1939604',
#  'CHEMBL1939604',
#  'CHEMBL1939605',
#  'CHEMBL1939606',
#  'CHEMBL1939606',
#  'CHEMBL1939607',
#  'CHEMBL1939607',
#  'CHEMBL1939608',
#  'CHEMBL1939609',
#  'CHEMBL1939610',
#  'CHEMBL1939611',
#  'CHEMBL1939612',
#  'CHEMBL1939613',
#  'CHEMBL1939614',
#  'CHEMBL1939615',
#  'CHEMBL1939616',
#  'CHEMBL1939731',
#  'CHEMBL1939732',
#  'CHEMBL1939733',
#  'CHEMBL1939734',
#  'CHEMBL1950459',
#  'CHEMBL277864',
#  'CHEMBL197209',
#  'CHEMBL1950460',
#  'CHEMBL1950461',
#  'CHEMBL1950462',
#  'CHEMBL23440',
#  'CHEMBL1950463',
#  'CHEMBL1950464',
#  'CHEMBL1950465',
#  'CHEMBL1950466',
#  'CHEMBL280180',
#  'CHEMBL1950467',
#  'CHEMBL1950468',
#  'CHEMBL1950469',
#  'CHEMBL1950470',
#  'CHEMBL1950471',
#  'CHEMBL1950472',
#  'CHEMBL1950473',
#  'CHEMBL1950474',
#  'CHEMBL1950475',
#  'CHEMBL1950476',
#  'CHEMBL1950477',
#  'CHEMBL1950478',
#  'CHEMBL1950479',
#  'CHEMBL290960',
#  'CHEMBL1958422',
#  'CHEMBL1958431',
#  'CHEMBL1958423',
#  'CHEMBL1958433',
#  'CHEMBL1958425',
#  'CHEMBL1958426',
#  'CHEMBL1958424',
#  'CHEMBL1958427',
#  'CHEMBL1958432',
#  'CHEMBL1958428',
#  'CHEMBL1958429',
#  'CHEMBL1958437',
#  'CHEMBL1958436',
#  'CHEMBL1958430',
#  'CHEMBL1958434',
#  'CHEMBL1958438',
#  'CHEMBL1958435',
#  'CHEMBL272847',
#  'CHEMBL1958440',
#  'CHEMBL1958439',
#  'CHEMBL1955942',
#  'CHEMBL453755',
#  'CHEMBL490018',
#  'CHEMBL1955943',
#  'CHEMBL1935529',
#  'CHEMBL1935655',
#  'CHEMBL1935654',
#  'CHEMBL1935653',
#  'CHEMBL1935652',
#  'CHEMBL1935651',
#  'CHEMBL1935650',
#  'CHEMBL1935554',
#  'CHEMBL1935649',
#  'CHEMBL1935553',
#  'CHEMBL1935552',
#  'CHEMBL1935550',
#  'CHEMBL1935551',
#  'CHEMBL1935549',
#  'CHEMBL1935548',
#  'CHEMBL1935547',
#  'CHEMBL1935546',
#  'CHEMBL1935545',
#  'CHEMBL1935544',
#  'CHEMBL1935543',
#  'CHEMBL1935542',
#  'CHEMBL1935540',
#  'CHEMBL1935541',
#  'CHEMBL1935539',
#  'CHEMBL1935538',
#  'CHEMBL1935537',
#  'CHEMBL1935536',
#  'CHEMBL1935535',
#  'CHEMBL1935534',
#  'CHEMBL1935533',
#  'CHEMBL1935532',
#  'CHEMBL1935531',
#  'CHEMBL1935530',
#  'CHEMBL9514',
#  'CHEMBL159',
#  'CHEMBL107',
#  'CHEMBL20684',
#  'CHEMBL49642',
#  'CHEMBL428647',
#  'CHEMBL1935656',
#  'CHEMBL1935657',
#  'CHEMBL1935658',
#  'CHEMBL1935659',
#  'CHEMBL1935660',
#  'CHEMBL1935661',
#  'CHEMBL574422',
#  'CHEMBL574213',
#  'CHEMBL270915',
#  'CHEMBL409271',
#  'CHEMBL55140',
#  'CHEMBL144896',
#  'CHEMBL1256928',
#  'CHEMBL1256964',
#  'CHEMBL2158071',
#  'CHEMBL2158072',
#  'CHEMBL1256401',
#  'CHEMBL1256965',
#  'CHEMBL1256966',
#  'CHEMBL1256989',
#  'CHEMBL1257016',
#  'CHEMBL1256991',
#  'CHEMBL1256990',
#  'CHEMBL1257018',
#  'CHEMBL1257017',
#  'CHEMBL290960',
#  'CHEMBL2165514',
#  'CHEMBL290960',
#  'CHEMBL830',
#  'CHEMBL2165518',
#  'CHEMBL2165517',
#  'CHEMBL2165516',
#  'CHEMBL2165515',
#  'CHEMBL2165514',
#  'CHEMBL2165397',
#  'CHEMBL2165396',
#  'CHEMBL2165395',
#  'CHEMBL166',
#  'CHEMBL830',
#  'CHEMBL55',
#  'CHEMBL265502',
#  'CHEMBL2402110',
#  'CHEMBL88734',
#  'CHEMBL108035',
#  'CHEMBL323975',
#  'CHEMBL111632',
#  'CHEMBL108865',
#  'CHEMBL107612',
#  'CHEMBL109619',
#  'CHEMBL108700',
#  'CHEMBL109893',
#  'CHEMBL326220',
#  'CHEMBL73007',
#  'CHEMBL3219799',
#  'CHEMBL3219784',
#  'CHEMBL3219783',
#  'CHEMBL3219788',
#  'CHEMBL3219791',
#  'CHEMBL3219798',
#  'CHEMBL3219790',
#  'CHEMBL3219785',
#  'CHEMBL3219787',
#  'CHEMBL3219789',
#  'CHEMBL3219786',
#  'CHEMBL3219797',
#  'CHEMBL3219794',
#  'CHEMBL959',
#  'CHEMBL3219792',
#  'CHEMBL3219795',
#  'CHEMBL3219796',
#  'CHEMBL3219793',
#  'CHEMBL3219801',
#  'CHEMBL3219800',
#  'CHEMBL660',
#  'CHEMBL3181863',
#  'CHEMBL3235266',
#  'CHEMBL3235267',
#  'CHEMBL3235268',
#  'CHEMBL3235269',
#  'CHEMBL55',
#  'CHEMBL110',
#  'CHEMBL3181863',
#  'CHEMBL3235266',
#  'CHEMBL3235267',
#  'CHEMBL3235268',
#  'CHEMBL3235269',
#  'CHEMBL55',
#  'CHEMBL110',
#  'CHEMBL3355359',
#  'CHEMBL3353039',
#  'CHEMBL3353040',
#  'CHEMBL3353041',
#  'CHEMBL3353042',
#  'CHEMBL3353043',
#  'CHEMBL140476',
#  'CHEMBL55',
#  'CHEMBL3356852',
#  'CHEMBL3356851',
#  'CHEMBL3356850',
#  'CHEMBL3356849',
#  'CHEMBL3356848',
#  'CHEMBL3356847',
#  'CHEMBL3356846',
#  'CHEMBL3356845',
#  'CHEMBL3356844',
#  'CHEMBL3356843',
#  'CHEMBL3356842',
#  'CHEMBL3356841',
#  'CHEMBL121024',
#  'CHEMBL3356840',
#  'CHEMBL3356839',
#  'CHEMBL3356838',
#  'CHEMBL3356837',
#  'CHEMBL1795628',
#  'CHEMBL3309536',
#  'CHEMBL440598',
#  'CHEMBL3309541',
#  'CHEMBL3309542',
#  'CHEMBL3309543',
#  'CHEMBL3309544',
#  'CHEMBL3309545',
#  'CHEMBL3309546',
#  'CHEMBL55',
#  'CHEMBL830',
#  'CHEMBL269538',
#  'CHEMBL3600556',
#  'CHEMBL3600555',
#  'CHEMBL3600554',
#  'CHEMBL3600553',
#  'CHEMBL3600552',
#  'CHEMBL3600551',
#  'CHEMBL3600550',
#  'CHEMBL1187774',
#  'CHEMBL3600549',
#  'CHEMBL1187001',
#  'CHEMBL3600468',
#  'CHEMBL1186058',
#  'CHEMBL1186370',
#  'CHEMBL1187082',
#  'CHEMBL3600467',
#  'CHEMBL3600466',
#  'CHEMBL3600465',
#  'CHEMBL3600464',
#  'CHEMBL3600463',
#  'CHEMBL2021659',
#  'CHEMBL2021669',
#  'CHEMBL252424',
#  ...]

# %%
# Iterating canonical SMILES into a list
canonical_smiles = []
for i in df_assays.canonical_smiles:
    canonical_smiles.append(i)

# %%
# Iterating standard_value into a list
standard_value = []
for i in df_assays.standard_value:
    standard_value.append(i)

# %%
# Combining the four variables into the same DataFrame
dados_tupla = list(zip(mol_cid, canonical_smiles, classe_bioatividade, standard_value))
df3 = pd.DataFrame( dados_tupla,  columns=['molecule_chembl_id', 'canonical_smiles', 'classe_bioatividade', 'standard_value'])

# %%
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0               CHEMBL55            N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1
# 1             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 2             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 3             CHEMBL9126         N=C(N)c1ccc(N2CCN(c3ccc(C(=N)N)cc3)CC2)cc1
# 4           CHEMBL267154  C(=C1/CCCN(c2ccc(C3=NCCN3)cc2)C1)\c1ccc(C2=NCC...
# ...                  ...                                                ...
# 21605      CHEMBL2314239  O=C(Cc1ccc(O)c(O)c1)NCCCCNCCCNC(=O)Cc1ccc(O)c(...
# 21606        CHEMBL41629            C(CCCNCCCNCC1CCCCCC1)CCCNCCCNCC1CCCCCC1
# 21607      CHEMBL5274443           CN(C)CCCNc1cc(Cl)ccc1Sc1ccc(C(F)(F)F)cc1
# 21608      CHEMBL5285392  Br.C[N+](C)(CCCNc1cc(Cl)ccc1Sc1ccccc1)Cc1ccc([...
# 21609      CHEMBL2040589  Oc1cc2cc(c1O)Oc1ccc(cc1)CCc1cccc(O)c1Oc1cccc(c...
#
#       classe_bioatividade standard_value
# 0                Inactive           35.0
# 1                Inactive           58.0
# 2                Inactive           16.0
# 3                Inactive           16.5
# 4                Inactive           71.0
# ...                   ...            ...
# 21605            Inactive         5900.0
# 21606            Inactive          160.0
# 21607            Inactive         1200.0
# 21608            Inactive          600.0
# 21609            Inactive         2090.0
#
# [21610 rows x 4 columns]

# %%
# Saving the DataFrame to a CSV file

df3.to_csv('dados_preprocessados.csv', index=False)
